# %%
tol = 1e-4
a = 1.0
b = 2.0
p = a + ((b - a)/ 2)
fp = pow(p, 3) + (4 * (p ** 2) -10)
fa = pow(a, 3) + (4 * (a ** 2) -10)
for i in range (25):
    
    if (fp == 0) | (((b-a)/2) < tol):
        print "El valor de p es: ", p
        break
    
    if ((fa * fp) > 0):
        a = p
        fa = fp
        print "a*fp>0"
        raw_input()
    
    if ((fa * fp) < 0):
        b = p
        print "a*fp<0"
        raw_input()
    
    p = a + ((b - a)/ 2)
    fp = pow(p, 3) + (4 * (p ** 2) -10)
    fa = pow(a, 3) + (4 * (a ** 2) -10)
    print "i: ", i+2, "a: ", a, "b: ", b, "p: ", p, "fp: ", fp
print "Fin!"
# Out:
# a*fp<0
#
# i:  2 a:  1.0 b:  1.5 p:  1.25 fp:  -1.796875
# a*fp>0
#
# i:  3 a:  1.25 b:  1.5 p:  1.375 fp:  0.162109375
# a*fp<0
#
# i:  4 a:  1.25 b:  1.375 p:  1.3125 fp:  -0.848388671875
# a*fp>0
#
# i:  5 a:  1.3125 b:  1.375 p:  1.34375 fp:  -0.350982666016
# a*fp>0
#
# i:  6 a:  1.34375 b:  1.375 p:  1.359375 fp:  -0.0964088439941
# a*fp>0
#
# i:  7 a:  1.359375 b:  1.375 p:  1.3671875 fp:  0.0323557853699
# a*fp<0
#
# i:  8 a:  1.359375 b:  1.3671875 p:  1.36328125 fp:  -0.0321499705315
# a*fp>0
#
# i:  9 a:  1.36328125 b:  1.3671875 p:  1.365234375 fp:  7.20247626305e-05
# a*fp<0
#
# i:  10 a:  1.36328125 b:  1.365234375 p:  1.3642578125 fp:  -0.0160466907546
# a*fp>0
#
# i:  11 a:  1.3642578125 b:  1.365234375 p:  1.36474609375 fp:  -0.00798926281277
# a*fp>0
#
# i:  12 a:  1.36474609375 b:  1.365234375 p:  1.36499023438 fp:  -0.00395910152292
# a*fp>0
#
# i:  13 a:  1.36499023438 b:  1.365234375 p:  1.36511230469 fp:  -0.00194365901007
# a*fp>0
#
# ...
